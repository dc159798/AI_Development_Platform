# %%
import os

# %%
import pandas as pd
import langchain
import openai
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import tensorflow as tf
import torch
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix
from flask import Flask, request
# Ya
from fastapi import FastAPI
from prometheus_client import start_http_server, Summary
import shap
import lime
import langchain

# %%
from transformers import AutoModel, AutoTokenizer
import requests

# Hugging Face API endpoint to list models
HF_MODELS_ENDPOINT = "https://huggingface.co/api/models"

def get_hf_models():
    response = requests.get(HF_MODELS_ENDPOINT)
    if response.status_code == 200:
        # Convert response to JSON
        models = response.json()
        # You can then process this list of models as needed
        return models
    else:
        print("Failed to fetch models")
        return []

# Call the function and print the list of models
models_list = get_hf_models()
print(models_list)
# Out:
# [{'_id': '621ffdc036468d709f174328', 'id': 'albert/albert-base-v1', 'likes': 6, 'private': False, 'downloads': 14250, 'tags': ['transformers', 'pytorch', 'tf', 'safetensors', 'albert', 'fill-mask', 'exbert', 'en', 'dataset:bookcorpus', 'dataset:wikipedia', 'arxiv:1909.11942', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'has_space', 'region:us'], 'pipeline_tag': 'fill-mask', 'library_name': 'transformers', 'createdAt': '2022-03-02T23:29:04.000Z', 'modelId': 'albert/albert-base-v1'}, {'_id': '621ffdc036468d709f174329', 'id': 'albert/albert-base-v2', 'likes': 87, 'private': False, 'downloads': 2503774, 'tags': ['transformers', 'pytorch', 'tf', 'jax', 'rust', 'safetensors', 'albert', 'fill-mask', 'en', 'dataset:bookcorpus', 'dataset:wikipedia', 'arxiv:1909.11942', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'has_space', 'region:us'], 'pipeline_tag': 'fill-mask', 'library_name': 'transformers', 'createdAt': '2022-03-02T23:29:04.000Z', 'm
# ...

# %%
from langchain import PromptTemplate, HuggingFaceHub, LLMChain

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Retrieve the API key
huggingface_api_key = os.getenv('HUGGINGFACE_API_KEY')

# Now you can use `huggingface_api_key` to authenticate with the Hugging Face API

# %%
# /app/services/huggingface.py

import requests
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()
# Out:
# False

# %%
from flask import Blueprint, request, jsonify
from app.services.huggingface import get_model_details

models_blueprint = Blueprint('models', __name__)

@models_blueprint.route('/models', methods=['GET'])
def list_models():
    # Yahan aap Hugging Face se models ki list fetch karke return karenge
    pass

@models_blueprint.route('/models/<model_id>', methods=['GET'])
def get_model(model_id):
    # Model details fetch karenge Hugging Face se
    details = get_model_details(model_id)
    return jsonify(details)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 from flask import Blueprint, request, jsonify
# ----> 2 from app.services.huggingface import get_model_details
#       4 models_blueprint = Blueprint('models', __name__)
#       6 @models_blueprint.route('/models', methods=['GET'])
#       7 def list_models():
#       8     # Yahan aap Hugging Face se models ki list fetch karke return karenge
#
# ModuleNotFoundError: No module named 'app'

# %%
import os
print(os.getcwd())
# Out:
# /home/haxck/Desktop/AI_Development_Platform/experiment
